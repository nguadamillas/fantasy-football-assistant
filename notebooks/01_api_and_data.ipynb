# %%
# Purpose:
#    Show that you can:
#    fetch the API
#    use caching
#    build Player objects
#    (using the src modules, not re-defining classes)

# %%
# sys.path + imports
from pathlib import Path
import sys

# Make src importable
ROOT = Path.cwd().parent
if str(ROOT) not in sys.path:
    sys.path.append(str(ROOT))

from src.data_api import fetch_bootstrap_static
from src.transform import build_player_objects

# %%
#fetch data and inspect
data = fetch_bootstrap_static(ttl_seconds=3600)

print("Top-level keys from API:")
print(data.keys())
# Out:
# Top-level keys from API:
# dict_keys(['chips', 'events', 'game_settings', 'game_config', 'phases', 'teams', 'total_players', 'element_stats', 'element_types', 'elements'])

# %%
#build players and inspect
player_objects = build_player_objects(data)

print("Number of players:", len(player_objects))
print("\nExample player:")
print(player_objects[0])
# Out:
# Number of players: 818
#
# Example player:
# Raya (Goalkeeper) - £6.0m
